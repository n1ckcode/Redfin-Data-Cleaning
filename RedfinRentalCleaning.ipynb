# %% [markdown]
# # Connect to web page

# %%
import requests
from bs4 import BeautifulSoup

url = "https://www.redfin.com/state/California/apartments-for-rent/filter/viewport=38.13751:37.17207:-121.37222:-123.06412"

headers = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:108.0) Gecko/20100101 Firefox/108.0"}

# Make a request to the website
response = requests.get(url, headers=headers)



# Parse the HTML content of the webpage
soup = BeautifulSoup(response.content, 'html.parser')

soup1 = BeautifulSoup(soup.prettify(),'html.parser')

# Extract the price, address and home stats
price = soup1.find(class_='homecardV2Price').get_text()
address = soup1.find(class_='homeAddressV2').get_text()
homestats = soup1.find(class_='HomeStatsV2 font-size-small').get_text()

stats = soup1.find(class_='stats').get_text()

print(stats)
# Out:
#                 1-2 Bed

# %% [markdown]
# # Scrape rental data

# %%
#Scrape rental data from all 9 pages

# %%
for i in range(1,10):
    urll = f"https://www.redfin.com/state/California/apartments-for-rent/filter/viewport=38.13751:37.17207:-121.37222:-123.06412/page-{i}"
    responses = requests.get(urll, headers=headers)
    soup = BeautifulSoup(responses.content, 'html.parser')

    prices = [item.get_text() for item in soup.find_all(class_='homecardV2Price')]
    addresses = [item.get_text() for item in soup.find_all(class_='homeAddressV2')]
    homestats = [item.get_text() for item in soup.find_all(class_='HomeStatsV2 font-size-small')]

    for j in range(len(prices)):
        print("Price:", prices[j])
        print("Address:", addresses[j])
        print("Home Stats:", homestats[j])
# Out:
# Price: $3,065-$5,890/mo
# Address: Redwood Place | 1030 Indian Wells Ave, Sunnyvale, CA 94085
# Home Stats: 1-2 Bed1-2 Bath563-1,276 Sq. Ft.
# Price: $3,235-$5,965/mo
# Address: Santa Clara Square | 3320 Montgomery Dr, Santa Clara, CA 95054
# Home Stats: 0-2 Beds1-2 Bath608-1,816 Sq. Ft.
# Price: $3,270-$4,555/mo
# Address: The Triton | 55 Triton Park Ln, Foster City, CA 94404
# Home Stats: 1-2 Bed1-2.5 Bath760-1,147 Sq. Ft.
# Price: $2,611-$3,362/mo
# Address: Woodland Meadow | 1600 Whitewood Dr, San Jose, CA 95131
# Home Stats: 1-2 Bed1-2 Bath836-1,119 Sq. Ft.
# Price: $3,060-$4,695/mo
# Address: Monticello | 3515-3585 Monroe St, Santa Clara, CA 95051
# Home Stats: 1-2 Bed1-2 Bath795-1,408 Sq. Ft.
# Price: $3,877-$6,614/mo
# Address: The Hadley | 555 E Evelyn Ave, Mountain View, CA 94041
# Home Stats: 0-3 Beds1-2 Bath644-1,355 Sq. Ft.
# Price: $3,340-$3,650/mo
# Address: The Blossoms at Brentwood | 2255 Amber Ln, Brentwood, CA 94513
# Home Stats: 2-3 Beds2 Baths922-1,251 Sq. Ft.
# Price: $3,157-$4,809/mo
# Address: Edgewater | 355 Berry St, San Francisco, CA 94158
# Home Stats: 1-2 Bed1-2 Bath535-1,330 Sq. Ft.
# Price: $3,145-$4,420/mo
# Address: Cherry Orchard | 250 W El Camino Real, Sunnyvale, CA 94087
# Home Stats: 1-2 Bed1-2 Bath761-1,104 Sq. Ft.
# Price: $4,874-$7,857/mo
# Home Stats: 0 Beds1 Bath432-452 Sq. Ft.
# Price: $2,580-$4,125/mo
# Address: 320 Crescent Village Cir, San Jose, CA 95134
# Home Stats: 0-2 Beds1-2 Bath574-1,282 Sq. Ft.
# Price: $3,975/mo
# Address: 1690 Sandyrock Ln, San Jose, CA 95125
# Home Stats: 2 Beds2 Baths1,479 Sq. Ft.
# Price: $3,040-$4,360/mo
# Address: Elan Mountain View | 1030 Castro St, Mountain View, CA 94040
# Home Stats: 0-2 Beds1-2 Bath590-1,082 Sq. Ft.
# Price: $2,717-$5,000/mo
# Address: Park Sierra | 6450 Dougherty Rd, Dublin, CA 94568
# Home Stats: 1-2 Bed1-2 Bath723-1,023 Sq. Ft.
# Price: $2,741-$3,384/mo
# Address: Tuscany Apartments | 3229 El Camino Real, Santa Clara, CA 95051
# Home Stats: 1-2 Bed1-2 Bath682-899 Sq. Ft.
# Price: $2,500/mo
# Address: 5725 Calmor Ave #1, San Jose, CA 95123
# Home Stats: 2 Beds1 Bath810 Sq. Ft.
# Price: $2,492-$4,026/mo
# Address: Sixth & Jackson Apartments | 620 N 6th St, San Jose, CA 95112
# Home Stats: 0-2 Beds1-2 Bath486-1,232 Sq. Ft.
# Price: $3,005-$3,875/mo
# Address: The Meadows | 1000 Escalon Ave, Sunnyvale, CA 94085
# Home Stats: 1-2 Bed1-2 Bath715-915 Sq. Ft.
# Price: $2,702-$4,638/mo
# Address: Ascent Apartments | 5805 Charlotte Dr, San Jose, CA 95123
# Home Stats: 1-3 Bed1-2 Bath706-1,395 Sq. Ft.
# Price: $4,000/mo
# Address: 4812 Touchstone Ter, Fremont, CA 94555
# Home Stats: 3 Beds2.5 Baths1,688 Sq. Ft.

# %% [markdown]
# # Structure data and export into CSV file

# %%
import requests
from bs4 import BeautifulSoup
import csv

headers = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:108.0) Gecko/20100101 Firefox/108.0"}

data = []

for i in range(1, 10):
    url = f"https://www.redfin.com/state/California/apartments-for-rent/filter/viewport=38.13751:37.17207:-121.37222:-123.06412/page-{i}"
    response = requests.get(url, headers=headers)
    soup = BeautifulSoup(response.content, 'html.parser')

    prices = [item.get_text() for item in soup.find_all(class_='homecardV2Price')]
    addresses = [item.get_text() for item in soup.find_all(class_='homeAddressV2')]
    homestats = [item.get_text() for item in soup.find_all(class_='HomeStatsV2 font-size-small')]

    for j in range(len(prices)):
        data.append([prices[j], addresses[j], homestats[j]])

with open("apartment_data.csv", "w", newline="") as f:
    writer = csv.writer(f)
    writer.writerow(["Price", "Address", "Home Stats"])
    writer.writerows(data)



print("created")
# Out:
# created

# %% [markdown]
# # Import excel file

# %%
import pandas as pd
#converted the csv file to an excel file instead because pandas was having trouble reading it
dff = pd.read_excel('redfinbayrentals.xlsx', sheet_name='redfin')

print(dff.head(10))
# Out:
#               Price                                            Address  \
# 0  $4,472-$8,057/mo  Sharon Green | 350 Sharon Park Dr, Menlo Park,...
# 1  $3,305-$5,380/mo  The Triton | 55 Triton Park Ln, Foster City, C...
# 2  $3,085-$6,080/mo  Redwood Place | 1030 Indian Wells Ave, Sunnyva...
# 3         $7,300/mo           570 La Mesa Dr, Portola Valley, CA 94028
# 4  $3,877-$6,563/mo  The Hadley | 555 E Evelyn Ave, Mountain View, ...
# 5  $3,340-$3,650/mo  The Blossoms at Brentwood | 2255 Amber Ln, Bre...
# 6  $2,850-$7,375/mo    The Brady | 1 Brady St, San Francisco, CA 94103
# 7         $3,900/mo            2616 Royal Ann Dr, Union City, CA 94587
# 8  $3,355-$5,760/mo  Santa Clara Square | 3320 Montgomery Dr, Santa...
# 9  $3,055-$4,725/mo  Monticello | 3515-3585 Monroe St, Santa Clara,...
#
#                            Home Stats
# 0    1-3 Bed1-2 Bath810-1,466 Sq. Ft.
# 1  1-3 Bed1-2.5 Bath760-1,392 Sq. Ft.
# 2    1-2 Bed1-2 Bath563-1,276 Sq. Ft.
# 3          3 Beds2 Baths1,740 Sq. Ft.
# 4   0-3 Beds1-2 Bath644-1,355 Sq. Ft.
# 5    2-3 Beds2 Baths922-1,251 Sq. Ft.
# 6   0-2 Beds1-2 Bath447-1,575 Sq. Ft.
# 7          4 Beds2 Baths2,169 Sq. Ft.
# 8   0-2 Beds1-2 Bath608-1,537 Sq. Ft.
# 9    1-2 Bed1-2 Bath798-1,408 Sq. Ft.

# %% [markdown]
# # Data cleaning and restructuring

# %%
# remove the '|'' and every string before it from values in the "Address" column
dff['Address'] = dff['Address'].str.split('|').str[-1]


dff
# Out:
#                 Price                                      Address  \
# 0    $4,472-$8,057/mo     350 Sharon Park Dr, Menlo Park, CA 94025
# 1    $3,305-$5,380/mo     55 Triton Park Ln, Foster City, CA 94404
# 2    $3,085-$6,080/mo   1030 Indian Wells Ave, Sunnyvale, CA 94085
# 3           $7,300/mo     570 La Mesa Dr, Portola Valley, CA 94028
# 4    $3,877-$6,563/mo    555 E Evelyn Ave, Mountain View, CA 94041
# ..                ...                                          ...
# 315         $3,000/mo         425 2nd Ave, San Francisco, CA 94118
# 316         $2,900/mo    280 Easy St #501, Mountain View, CA 94043
# 317         $6,850/mo    6840 Charing Cross Rd, Berkeley, CA 94705
# 318        $12,000/mo        111 30th Ave, San Francisco, CA 94121
# 319         $3,450/mo      1320 Windswept Cmn, Livermore, CA 94550
#
#                              Home Stats
# 0      1-3 Bed1-2 Bath810-1,466 Sq. Ft.
# 1    1-3 Bed1-2.5 Bath760-1,392 Sq. Ft.
# 2      1-2 Bed1-2 Bath563-1,276 Sq. Ft.
# 3            3 Beds2 Baths1,740 Sq. Ft.
# 4     0-3 Beds1-2 Bath644-1,355 Sq. Ft.
# ..                                  ...
# 315              1 Bed1 Bath851 Sq. Ft.
# 316             2 Beds1 Bath894 Sq. Ft.
# 317        5 Beds3.5 Baths3,908 Sq. Ft.
# 318          4 Beds3 Baths3,100 Sq. Ft.
# 319        3 Beds3.5 Baths1,757 Sq. Ft.
#
# [320 rows x 3 columns]

# %%
# split the values in the "Address" column of the DataFrame dff into separate columns for "Address", "City", and "State".
dff['Address'].str.rsplit(',', 2).apply(lambda x: x[0] if len(x) == 3 else x[0] + ',' + x[1])
dff = dff.assign(
    Address=dff['Address'].str.rsplit(',', 2).apply(lambda x: x[0] if len(x) == 3 else x[0] + ',' + x[1]),
    City=dff['Address'].str.rsplit(',', 2).apply(lambda x: x[1] if len(x) == 3 else None),
    State=dff['Address'].str.rsplit(',', 2).apply(lambda x: x[2] if len(x) == 3 else None)
)
dff
# Out:
# C:\Users\yaboy\AppData\Local\Temp\ipykernel_9628\627500783.py:2: FutureWarning: In a future version of pandas all arguments of StringMethods.rsplit except for the argument 'pat' will be keyword-only.
#   dff['Address'].str.rsplit(',', 2).apply(lambda x: x[0] if len(x) == 3 else x[0] + ',' + x[1])
# C:\Users\yaboy\AppData\Local\Temp\ipykernel_9628\627500783.py:4: FutureWarning: In a future version of pandas all arguments of StringMethods.rsplit except for the argument 'pat' will be keyword-only.
#   Address=dff['Address'].str.rsplit(',', 2).apply(lambda x: x[0] if len(x) == 3 else x[0] + ',' + x[1]),
# C:\Users\yaboy\AppData\Local\Temp\ipykernel_9628\627500783.py:5: FutureWarning: In a future version of pandas all arguments of StringMethods.rsplit except for the argument 'pat' will be keyword-only.
#   City=dff['Address'].str.rsplit(',', 2).apply(lambda x: x[1] if len(x) == 3 else None),
# C:\Users\yaboy\AppData\Local\Temp\ipykernel_9628\627500783.py:6: FutureWarning: In a future version of pandas all arguments of StringMethods.rsplit except for the argument 'pat' will be keyword-only.
#   State=dff['Address'].str.rsplit(',', 2).apply(lambda x: x[2] if len(x) == 3 else None)
#                 Price                 Address  \
# 0    $4,472-$8,057/mo      350 Sharon Park Dr
# 1    $3,305-$5,380/mo       55 Triton Park Ln
# 2    $3,085-$6,080/mo   1030 Indian Wells Ave
# 3           $7,300/mo          570 La Mesa Dr
# 4    $3,877-$6,563/mo        555 E Evelyn Ave
# ..                ...                     ...
# 315         $3,000/mo             425 2nd Ave
# 316         $2,900/mo        280 Easy St #501
# 317         $6,850/mo   6840 Charing Cross Rd
# 318        $12,000/mo            111 30th Ave
# 319         $3,450/mo      1320 Windswept Cmn
#
#                              Home Stats             City      State
# 0      1-3 Bed1-2 Bath810-1,466 Sq. Ft.       Menlo Park   CA 94025
# 1    1-3 Bed1-2.5 Bath760-1,392 Sq. Ft.      Foster City   CA 94404
# 2      1-2 Bed1-2 Bath563-1,276 Sq. Ft.        Sunnyvale   CA 94085
# 3            3 Beds2 Baths1,740 Sq. Ft.   Portola Valley   CA 94028
# 4     0-3 Beds1-2 Bath644-1,355 Sq. Ft.    Mountain View   CA 94041
# ..                                  ...              ...        ...
# 315              1 Bed1 Bath851 Sq. Ft.    San Francisco   CA 94118
# 316             2 Beds1 Bath894 Sq. Ft.    Mountain View   CA 94043
# 317        5 Beds3.5 Baths3,908 Sq. Ft.         Berkeley   CA 94705
# 318          4 Beds3 Baths3,100 Sq. Ft.    San Francisco   CA 94121
# 319        3 Beds3.5 Baths1,757 Sq. Ft.        Livermore   CA 94550
#
# [320 rows x 5 columns]

# %%
# extract the ZipCode from the "State" column of the DataFrame dff and then remove it from the "State" column, creates a new column for the zip code
dff['ZipCode'] = dff['State'].str.extract(r'(\d{5})')
dff['State'] = dff['State'].str.replace(r' \d{5}', '')

dff
# Out:
# C:\Users\yaboy\AppData\Local\Temp\ipykernel_9628\1065006877.py:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   dff['State'] = dff['State'].str.replace(r' \d{5}', '')
#                 Price                 Address  \
# 0    $4,472-$8,057/mo      350 Sharon Park Dr
# 1    $3,305-$5,380/mo       55 Triton Park Ln
# 2    $3,085-$6,080/mo   1030 Indian Wells Ave
# 3           $7,300/mo          570 La Mesa Dr
# 4    $3,877-$6,563/mo        555 E Evelyn Ave
# ..                ...                     ...
# 315         $3,000/mo             425 2nd Ave
# 316         $2,900/mo        280 Easy St #501
# 317         $6,850/mo   6840 Charing Cross Rd
# 318        $12,000/mo            111 30th Ave
# 319         $3,450/mo      1320 Windswept Cmn
#
#                              Home Stats             City State ZipCode
# 0      1-3 Bed1-2 Bath810-1,466 Sq. Ft.       Menlo Park    CA   94025
# 1    1-3 Bed1-2.5 Bath760-1,392 Sq. Ft.      Foster City    CA   94404
# 2      1-2 Bed1-2 Bath563-1,276 Sq. Ft.        Sunnyvale    CA   94085
# 3            3 Beds2 Baths1,740 Sq. Ft.   Portola Valley    CA   94028
# 4     0-3 Beds1-2 Bath644-1,355 Sq. Ft.    Mountain View    CA   94041
# ..                                  ...              ...   ...     ...
# 315              1 Bed1 Bath851 Sq. Ft.    San Francisco    CA   94118
# 316             2 Beds1 Bath894 Sq. Ft.    Mountain View    CA   94043
# 317        5 Beds3.5 Baths3,908 Sq. Ft.         Berkeley    CA   94705
# 318          4 Beds3 Baths3,100 Sq. Ft.    San Francisco    CA   94121
# 319        3 Beds3.5 Baths1,757 Sq. Ft.        Livermore    CA   94550
#
# [320 rows x 6 columns]

# %%
# replace values in the 'Home Stats' column of a Pandas DataFrame dff. The argument r'\d+-' is a regular expression pattern that matches one or more consecutive digits (\d+) followed by a hyphen (-).

dff['Home Stats'] = dff['Home Stats'].str.replace(r'\d+-', '')

dff
# Out:
# C:\Users\yaboy\AppData\Local\Temp\ipykernel_9628\78441521.py:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   dff['Home Stats'] = dff['Home Stats'].str.replace(r'\d+-', '')
#                 Price                 Address                    Home Stats  \
# 0    $4,472-$8,057/mo      350 Sharon Park Dr      3 Bed2 Bath1,466 Sq. Ft.
# 1    $3,305-$5,380/mo       55 Triton Park Ln    3 Bed2.5 Bath1,392 Sq. Ft.
# 2    $3,085-$6,080/mo   1030 Indian Wells Ave      2 Bed2 Bath1,276 Sq. Ft.
# 3           $7,300/mo          570 La Mesa Dr    3 Beds2 Baths1,740 Sq. Ft.
# 4    $3,877-$6,563/mo        555 E Evelyn Ave     3 Beds2 Bath1,355 Sq. Ft.
# ..                ...                     ...                           ...
# 315         $3,000/mo             425 2nd Ave        1 Bed1 Bath851 Sq. Ft.
# 316         $2,900/mo        280 Easy St #501       2 Beds1 Bath894 Sq. Ft.
# 317         $6,850/mo   6840 Charing Cross Rd  5 Beds3.5 Baths3,908 Sq. Ft.
# 318        $12,000/mo            111 30th Ave    4 Beds3 Baths3,100 Sq. Ft.
# 319         $3,450/mo      1320 Windswept Cmn  3 Beds3.5 Baths1,757 Sq. Ft.
#
#                 City State ZipCode
# 0         Menlo Park    CA   94025
# 1        Foster City    CA   94404
# 2          Sunnyvale    CA   94085
# 3     Portola Valley    CA   94028
# 4      Mountain View    CA   94041
# ..               ...   ...     ...
# 315    San Francisco    CA   94118
# 316    Mountain View    CA   94043
# 317         Berkeley    CA   94705
# 318    San Francisco    CA   94121
# 319        Livermore    CA   94550
#
# [320 rows x 6 columns]

# %%
# change the name of a column in the dff DataFrame.
dff.rename(columns={"Home Stats": "Size"}, inplace=True)
dff
# Out:
#                 Price                 Address                          Size  \
# 0    $4,472-$8,057/mo      350 Sharon Park Dr      3 Bed2 Bath1,466 Sq. Ft.
# 1    $3,305-$5,380/mo       55 Triton Park Ln    3 Bed2.5 Bath1,392 Sq. Ft.
# 2    $3,085-$6,080/mo   1030 Indian Wells Ave      2 Bed2 Bath1,276 Sq. Ft.
# 3           $7,300/mo          570 La Mesa Dr    3 Beds2 Baths1,740 Sq. Ft.
# 4    $3,877-$6,563/mo        555 E Evelyn Ave     3 Beds2 Bath1,355 Sq. Ft.
# ..                ...                     ...                           ...
# 315         $3,000/mo             425 2nd Ave        1 Bed1 Bath851 Sq. Ft.
# 316         $2,900/mo        280 Easy St #501       2 Beds1 Bath894 Sq. Ft.
# 317         $6,850/mo   6840 Charing Cross Rd  5 Beds3.5 Baths3,908 Sq. Ft.
# 318        $12,000/mo            111 30th Ave    4 Beds3 Baths3,100 Sq. Ft.
# 319         $3,450/mo      1320 Windswept Cmn  3 Beds3.5 Baths1,757 Sq. Ft.
#
#                 City State ZipCode
# 0         Menlo Park    CA   94025
# 1        Foster City    CA   94404
# 2          Sunnyvale    CA   94085
# 3     Portola Valley    CA   94028
# 4      Mountain View    CA   94041
# ..               ...   ...     ...
# 315    San Francisco    CA   94118
# 316    Mountain View    CA   94043
# 317         Berkeley    CA   94705
# 318    San Francisco    CA   94121
# 319        Livermore    CA   94550
#
# [320 rows x 6 columns]

# %%
# re format returns a formatted string based on the contents of s

import re 
def format_size(s):
    parts = re.findall(r'(\d+)\s*[Bb]ed.*?(\d+)\s*[Bb]ath.*?(\d+,\d+)\s*[Ss]q\s*[.]\s*[Ff]t\.', s)
    if parts:
        beds, baths, sqft = parts[0]
        return f"{beds} Beds, {baths} Baths, {sqft} Sq. Ft."
    return s

dff["Size"] = dff["Size"].apply(format_size)


dff
# Out:
#                 Price                 Address                            Size  \
# 0    $4,472-$8,057/mo      350 Sharon Park Dr  3 Beds, 2 Baths, 1,466 Sq. Ft.
# 1    $3,305-$5,380/mo       55 Triton Park Ln  3 Beds, 5 Baths, 1,392 Sq. Ft.
# 2    $3,085-$6,080/mo   1030 Indian Wells Ave  2 Beds, 2 Baths, 1,276 Sq. Ft.
# 3           $7,300/mo          570 La Mesa Dr  3 Beds, 2 Baths, 1,740 Sq. Ft.
# 4    $3,877-$6,563/mo        555 E Evelyn Ave  3 Beds, 2 Baths, 1,355 Sq. Ft.
# ..                ...                     ...                             ...
# 315         $3,000/mo             425 2nd Ave          1 Bed1 Bath851 Sq. Ft.
# 316         $2,900/mo        280 Easy St #501         2 Beds1 Bath894 Sq. Ft.
# 317         $6,850/mo   6840 Charing Cross Rd  5 Beds, 5 Baths, 3,908 Sq. Ft.
# 318        $12,000/mo            111 30th Ave  4 Beds, 3 Baths, 3,100 Sq. Ft.
# 319         $3,450/mo      1320 Windswept Cmn  3 Beds, 5 Baths, 1,757 Sq. Ft.
#
#                 City State ZipCode
# 0         Menlo Park    CA   94025
# 1        Foster City    CA   94404
# 2          Sunnyvale    CA   94085
# 3     Portola Valley    CA   94028
# 4      Mountain View    CA   94041
# ..               ...   ...     ...
# 315    San Francisco    CA   94118
# 316    Mountain View    CA   94043
# 317         Berkeley    CA   94705
# 318    San Francisco    CA   94121
# 319        Livermore    CA   94550
#
# [320 rows x 6 columns]

# %%
# Out:
#                 Price                 Address                            Size  \
# 0    $4,472-$8,057/mo      350 Sharon Park Dr  3 Beds, 2 Baths, 1,466 Sq. Ft.
# 1    $3,305-$5,380/mo       55 Triton Park Ln  3 Beds, 5 Baths, 1,392 Sq. Ft.
# 2    $3,085-$6,080/mo   1030 Indian Wells Ave  2 Beds, 2 Baths, 1,276 Sq. Ft.
# 3           $7,300/mo          570 La Mesa Dr  3 Beds, 2 Baths, 1,740 Sq. Ft.
# 4    $3,877-$6,563/mo        555 E Evelyn Ave  3 Beds, 2 Baths, 1,355 Sq. Ft.
# ..                ...                     ...                             ...
# 315         $3,000/mo             425 2nd Ave          1 Bed1 Bath851 Sq. Ft.
# 316         $2,900/mo        280 Easy St #501         2 Beds1 Bath894 Sq. Ft.
# 317         $6,850/mo   6840 Charing Cross Rd  5 Beds, 5 Baths, 3,908 Sq. Ft.
# 318        $12,000/mo            111 30th Ave  4 Beds, 3 Baths, 3,100 Sq. Ft.
# 319         $3,450/mo      1320 Windswept Cmn  3 Beds, 5 Baths, 1,757 Sq. Ft.
#
#                 City State ZipCode
# 0         Menlo Park    CA   94025
# 1        Foster City    CA   94404
# 2          Sunnyvale    CA   94085
# 3     Portola Valley    CA   94028
# 4      Mountain View    CA   94041
# ..               ...   ...     ...
# 315    San Francisco    CA   94118
# 316    Mountain View    CA   94043
# 317         Berkeley    CA   94705
# 318    San Francisco    CA   94121
# 319        Livermore    CA   94550
#
# [320 rows x 6 columns]

# %%
# Out:
#                 Price                 Address                            Size  \
# 0    $4,472-$8,057/mo      350 Sharon Park Dr  3 Beds, 2 Baths, 1,466 Sq. Ft.
# 1    $3,305-$5,380/mo       55 Triton Park Ln  3 Beds, 5 Baths, 1,392 Sq. Ft.
# 2    $3,085-$6,080/mo   1030 Indian Wells Ave  2 Beds, 2 Baths, 1,276 Sq. Ft.
# 3           $7,300/mo          570 La Mesa Dr  3 Beds, 2 Baths, 1,740 Sq. Ft.
# 4    $3,877-$6,563/mo        555 E Evelyn Ave  3 Beds, 2 Baths, 1,355 Sq. Ft.
# ..                ...                     ...                             ...
# 315         $3,000/mo             425 2nd Ave    1 Beds, 1 Baths, 851 Sq. Ft.
# 316         $2,900/mo        280 Easy St #501    2 Beds, 1 Baths, 894 Sq. Ft.
# 317         $6,850/mo   6840 Charing Cross Rd  5 Beds, 5 Baths, 3,908 Sq. Ft.
# 318        $12,000/mo            111 30th Ave  4 Beds, 3 Baths, 3,100 Sq. Ft.
# 319         $3,450/mo      1320 Windswept Cmn  3 Beds, 5 Baths, 1,757 Sq. Ft.
#
#                 City State ZipCode
# 0         Menlo Park    CA   94025
# 1        Foster City    CA   94404
# 2          Sunnyvale    CA   94085
# 3     Portola Valley    CA   94028
# 4      Mountain View    CA   94041
# ..               ...   ...     ...
# 315    San Francisco    CA   94118
# 316    Mountain View    CA   94043
# 317         Berkeley    CA   94705
# 318    San Francisco    CA   94121
# 319        Livermore    CA   94550
#
# [320 rows x 6 columns]

# %%
# reformat the values in the "Size" column by using string operations and regular expressions.

import re

def format_size(s):
    parts = re.findall(r'(\d+)\s*[Bb]ed.*?(\d+)\s*[Bb]ath.*?(\d+,\d+)\s*[Ss]q\s*[.]\s*[Ff]t\.', s)
    if parts:
        beds, baths, sqft = parts[0]
        if beds == '1':
            beds = '1 Bed'
        else:
            beds = f"{beds} Beds"
        if baths == '1':
            baths = '1 Bath'
        else:
            baths = f"{baths} Baths"
        return f"{beds}, {baths}, {int(sqft.replace(',', '')):,} Sq. Ft."
    parts = re.findall(r'(\d+)\s*[Bb]ed.*?(\d+)\s*[Bb]ath.*?(\d+)\s*[Ss]q\s*[.]\s*[Ff]t\.', s)
    if parts:
        beds, baths, sqft = parts[0]
        if beds == '1':
            beds = '1 Bed'
        else:
            beds = f"{beds} Beds"
        if baths == '1':
            baths = '1 Bath'
        else:
            baths = f"{baths} Baths"
        return f"{beds}, {baths}, {int(sqft):,} Sq. Ft."
    return s

dff["Size"] = dff["Size"].apply(format_size)

dff
# Out:
#                 Price                 Address                            Size  \
# 0    $4,472-$8,057/mo      350 Sharon Park Dr  3 Beds, 2 Baths, 1,466 Sq. Ft.
# 1    $3,305-$5,380/mo       55 Triton Park Ln  3 Beds, 5 Baths, 1,392 Sq. Ft.
# 2    $3,085-$6,080/mo   1030 Indian Wells Ave  2 Beds, 2 Baths, 1,276 Sq. Ft.
# 3           $7,300/mo          570 La Mesa Dr  3 Beds, 2 Baths, 1,740 Sq. Ft.
# 4    $3,877-$6,563/mo        555 E Evelyn Ave  3 Beds, 2 Baths, 1,355 Sq. Ft.
# ..                ...                     ...                             ...
# 315         $3,000/mo             425 2nd Ave      1 Bed, 1 Bath, 851 Sq. Ft.
# 316         $2,900/mo        280 Easy St #501     2 Beds, 1 Bath, 894 Sq. Ft.
# 317         $6,850/mo   6840 Charing Cross Rd  5 Beds, 5 Baths, 3,908 Sq. Ft.
# 318        $12,000/mo            111 30th Ave  4 Beds, 3 Baths, 3,100 Sq. Ft.
# 319         $3,450/mo      1320 Windswept Cmn  3 Beds, 5 Baths, 1,757 Sq. Ft.
#
#                 City State ZipCode
# 0         Menlo Park    CA   94025
# 1        Foster City    CA   94404
# 2          Sunnyvale    CA   94085
# 3     Portola Valley    CA   94028
# 4      Mountain View    CA   94041
# ..               ...   ...     ...
# 315    San Francisco    CA   94118
# 316    Mountain View    CA   94043
# 317         Berkeley    CA   94705
# 318    San Francisco    CA   94121
# 319        Livermore    CA   94550
#
# [320 rows x 6 columns]

# %%
# Out:
# hi

# %%
# first we need to remove the "/mo" part of the string
dff['Price'] = dff['Price'].str.replace("/mo", "")

# next, we need to remove the dash and everything after it
dff['Price'] = dff['Price'].str.replace(r'-.*', '')

# finally, we need to remove the comma separators in the numbers and add a "$" sign
dff['Price'] = "$" + dff['Price'].str.replace(',', '')

dff
# Out:
# C:\Users\yaboy\AppData\Local\Temp\ipykernel_9628\3565541582.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   dff['Price'] = dff['Price'].str.replace(r'-.*', '')
#        Price                 Address                            Size  \
# 0     $$4472      350 Sharon Park Dr  3 Beds, 2 Baths, 1,466 Sq. Ft.
# 1     $$3305       55 Triton Park Ln  3 Beds, 5 Baths, 1,392 Sq. Ft.
# 2     $$3085   1030 Indian Wells Ave  2 Beds, 2 Baths, 1,276 Sq. Ft.
# 3     $$7300          570 La Mesa Dr  3 Beds, 2 Baths, 1,740 Sq. Ft.
# 4     $$3877        555 E Evelyn Ave  3 Beds, 2 Baths, 1,355 Sq. Ft.
# ..       ...                     ...                             ...
# 315   $$3000             425 2nd Ave      1 Bed, 1 Bath, 851 Sq. Ft.
# 316   $$2900        280 Easy St #501     2 Beds, 1 Bath, 894 Sq. Ft.
# 317   $$6850   6840 Charing Cross Rd  5 Beds, 5 Baths, 3,908 Sq. Ft.
# 318  $$12000            111 30th Ave  4 Beds, 3 Baths, 3,100 Sq. Ft.
# 319   $$3450      1320 Windswept Cmn  3 Beds, 5 Baths, 1,757 Sq. Ft.
#
#                 City State ZipCode
# 0         Menlo Park    CA   94025
# 1        Foster City    CA   94404
# 2          Sunnyvale    CA   94085
# 3     Portola Valley    CA   94028
# 4      Mountain View    CA   94041
# ..               ...   ...     ...
# 315    San Francisco    CA   94118
# 316    Mountain View    CA   94043
# 317         Berkeley    CA   94705
# 318    San Francisco    CA   94121
# 319        Livermore    CA   94550
#
# [320 rows x 6 columns]

# %%
# remove the extra "$" sign
dff['Price'] = dff['Price'].str.replace("$", "")
# add the "$" sign
dff['Price'] = "$" + dff['Price']

dff
# Out:
# C:\Users\yaboy\AppData\Local\Temp\ipykernel_9628\1451249079.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   dff['Price'] = dff['Price'].str.replace("$", "")
#       Price                 Address                            Size  \
# 0     $4472      350 Sharon Park Dr  3 Beds, 2 Baths, 1,466 Sq. Ft.
# 1     $3305       55 Triton Park Ln  3 Beds, 5 Baths, 1,392 Sq. Ft.
# 2     $3085   1030 Indian Wells Ave  2 Beds, 2 Baths, 1,276 Sq. Ft.
# 3     $7300          570 La Mesa Dr  3 Beds, 2 Baths, 1,740 Sq. Ft.
# 4     $3877        555 E Evelyn Ave  3 Beds, 2 Baths, 1,355 Sq. Ft.
# ..      ...                     ...                             ...
# 315   $3000             425 2nd Ave      1 Bed, 1 Bath, 851 Sq. Ft.
# 316   $2900        280 Easy St #501     2 Beds, 1 Bath, 894 Sq. Ft.
# 317   $6850   6840 Charing Cross Rd  5 Beds, 5 Baths, 3,908 Sq. Ft.
# 318  $12000            111 30th Ave  4 Beds, 3 Baths, 3,100 Sq. Ft.
# 319   $3450      1320 Windswept Cmn  3 Beds, 5 Baths, 1,757 Sq. Ft.
#
#                 City State ZipCode
# 0         Menlo Park    CA   94025
# 1        Foster City    CA   94404
# 2          Sunnyvale    CA   94085
# 3     Portola Valley    CA   94028
# 4      Mountain View    CA   94041
# ..               ...   ...     ...
# 315    San Francisco    CA   94118
# 316    Mountain View    CA   94043
# 317         Berkeley    CA   94705
# 318    San Francisco    CA   94121
# 319        Livermore    CA   94550
#
# [320 rows x 6 columns]

# %%
# change the name of the "Price" column to "Monthly Rent"
dff.rename(columns={'Price': 'Monthly Rent'}, inplace=True)

dff
# Out:
#     Monthly Rent                 Address                            Size  \
# 0          $4472      350 Sharon Park Dr  3 Beds, 2 Baths, 1,466 Sq. Ft.
# 1          $3305       55 Triton Park Ln  3 Beds, 5 Baths, 1,392 Sq. Ft.
# 2          $3085   1030 Indian Wells Ave  2 Beds, 2 Baths, 1,276 Sq. Ft.
# 3          $7300          570 La Mesa Dr  3 Beds, 2 Baths, 1,740 Sq. Ft.
# 4          $3877        555 E Evelyn Ave  3 Beds, 2 Baths, 1,355 Sq. Ft.
# ..           ...                     ...                             ...
# 315        $3000             425 2nd Ave      1 Bed, 1 Bath, 851 Sq. Ft.
# 316        $2900        280 Easy St #501     2 Beds, 1 Bath, 894 Sq. Ft.
# 317        $6850   6840 Charing Cross Rd  5 Beds, 5 Baths, 3,908 Sq. Ft.
# 318       $12000            111 30th Ave  4 Beds, 3 Baths, 3,100 Sq. Ft.
# 319        $3450      1320 Windswept Cmn  3 Beds, 5 Baths, 1,757 Sq. Ft.
#
#                 City State ZipCode
# 0         Menlo Park    CA   94025
# 1        Foster City    CA   94404
# 2          Sunnyvale    CA   94085
# 3     Portola Valley    CA   94028
# 4      Mountain View    CA   94041
# ..               ...   ...     ...
# 315    San Francisco    CA   94118
# 316    Mountain View    CA   94043
# 317         Berkeley    CA   94705
# 318    San Francisco    CA   94121
# 319        Livermore    CA   94550
#
# [320 rows x 6 columns]

# %%
# Out:
#     Monthly Rent                 Address                                Size  \
# 0          $4472      350 Sharon Park Dr    1-3 Bed1-2 Bath810-1,466 Sq. Ft.
# 1          $3305       55 Triton Park Ln  1-3 Bed1-2.5 Bath760-1,392 Sq. Ft.
# 2          $3085   1030 Indian Wells Ave    1-2 Bed1-2 Bath563-1,276 Sq. Ft.
# 3          $7300          570 La Mesa Dr          3 Beds2 Baths1,740 Sq. Ft.
# 4          $3877        555 E Evelyn Ave   0-3 Beds1-2 Bath644-1,355 Sq. Ft.
# ..           ...                     ...                                 ...
# 315        $3000             425 2nd Ave              1 Bed1 Bath851 Sq. Ft.
# 316        $2900        280 Easy St #501             2 Beds1 Bath894 Sq. Ft.
# 317        $6850   6840 Charing Cross Rd        5 Beds3.5 Baths3,908 Sq. Ft.
# 318       $12000            111 30th Ave          4 Beds3 Baths3,100 Sq. Ft.
# 319        $3450      1320 Windswept Cmn        3 Beds3.5 Baths1,757 Sq. Ft.
#
#                 City State ZipCode
# 0         Menlo Park    CA   94025
# 1        Foster City    CA   94404
# 2          Sunnyvale    CA   94085
# 3     Portola Valley    CA   94028
# 4      Mountain View    CA   94041
# ..               ...   ...     ...
# 315    San Francisco    CA   94118
# 316    Mountain View    CA   94043
# 317         Berkeley    CA   94705
# 318    San Francisco    CA   94121
# 319        Livermore    CA   94550
#
# [320 rows x 6 columns]

# %%
# Extract the values using regex
dff[['Beds', 'Baths', 'SqFt']] = dff['Size'].str.extract(r'(\d+) Beds, (\d+) Baths, (\d+,\d+) Sq. Ft.', expand=True)

# Replace NaN values with 0
dff['SqFt'] = dff['SqFt'].str.replace(',', '').astype(float).fillna(0).astype(int)


dff
# Out:
#     Monthly Rent                 Address                            Size  \
# 0          $4472      350 Sharon Park Dr  3 Beds, 2 Baths, 1,466 Sq. Ft.
# 1          $3305       55 Triton Park Ln  3 Beds, 5 Baths, 1,392 Sq. Ft.
# 2          $3085   1030 Indian Wells Ave  2 Beds, 2 Baths, 1,276 Sq. Ft.
# 3          $7300          570 La Mesa Dr  3 Beds, 2 Baths, 1,740 Sq. Ft.
# 4          $3877        555 E Evelyn Ave  3 Beds, 2 Baths, 1,355 Sq. Ft.
# ..           ...                     ...                             ...
# 315        $3000             425 2nd Ave      1 Bed, 1 Bath, 851 Sq. Ft.
# 316        $2900        280 Easy St #501     2 Beds, 1 Bath, 894 Sq. Ft.
# 317        $6850   6840 Charing Cross Rd  5 Beds, 5 Baths, 3,908 Sq. Ft.
# 318       $12000            111 30th Ave  4 Beds, 3 Baths, 3,100 Sq. Ft.
# 319        $3450      1320 Windswept Cmn  3 Beds, 5 Baths, 1,757 Sq. Ft.
#
#                 City State ZipCode Beds Baths  SqFt
# 0         Menlo Park    CA   94025    3     2  1466
# 1        Foster City    CA   94404    3     5  1392
# 2          Sunnyvale    CA   94085    2     2  1276
# 3     Portola Valley    CA   94028    3     2  1740
# 4      Mountain View    CA   94041    3     2  1355
# ..               ...   ...     ...  ...   ...   ...
# 315    San Francisco    CA   94118  NaN   NaN     0
# 316    Mountain View    CA   94043  NaN   NaN     0
# 317         Berkeley    CA   94705    5     5  3908
# 318    San Francisco    CA   94121    4     3  3100
# 319        Livermore    CA   94550    3     5  1757
#
# [320 rows x 9 columns]

# %%
# drop the size column
dff.drop(['Size'], axis=1, inplace=True)

dff
# Out:
#     Monthly Rent                 Address             City State ZipCode Beds  \
# 0          $4472      350 Sharon Park Dr       Menlo Park    CA   94025    3
# 1          $3305       55 Triton Park Ln      Foster City    CA   94404    3
# 2          $3085   1030 Indian Wells Ave        Sunnyvale    CA   94085    2
# 3          $7300          570 La Mesa Dr   Portola Valley    CA   94028    3
# 4          $3877        555 E Evelyn Ave    Mountain View    CA   94041    3
# ..           ...                     ...              ...   ...     ...  ...
# 315        $3000             425 2nd Ave    San Francisco    CA   94118  NaN
# 316        $2900        280 Easy St #501    Mountain View    CA   94043  NaN
# 317        $6850   6840 Charing Cross Rd         Berkeley    CA   94705    5
# 318       $12000            111 30th Ave    San Francisco    CA   94121    4
# 319        $3450      1320 Windswept Cmn        Livermore    CA   94550    3
#
#     Baths  SqFt
# 0       2  1466
# 1       5  1392
# 2       2  1276
# 3       2  1740
# 4       2  1355
# ..    ...   ...
# 315   NaN     0
# 316   NaN     0
# 317     5  3908
# 318     3  3100
# 319     5  1757
#
# [320 rows x 8 columns]

# %%
# Replace NaN values with 0
dff['Beds'].fillna(0, inplace=True)
dff['Baths'].fillna(0, inplace=True)

dff
# Out:
#     Monthly Rent                 Address             City State ZipCode Beds  \
# 0          $4472      350 Sharon Park Dr       Menlo Park    CA   94025    3
# 1          $3305       55 Triton Park Ln      Foster City    CA   94404    3
# 2          $3085   1030 Indian Wells Ave        Sunnyvale    CA   94085    2
# 3          $7300          570 La Mesa Dr   Portola Valley    CA   94028    3
# 4          $3877        555 E Evelyn Ave    Mountain View    CA   94041    3
# ..           ...                     ...              ...   ...     ...  ...
# 315        $3000             425 2nd Ave    San Francisco    CA   94118    0
# 316        $2900        280 Easy St #501    Mountain View    CA   94043    0
# 317        $6850   6840 Charing Cross Rd         Berkeley    CA   94705    5
# 318       $12000            111 30th Ave    San Francisco    CA   94121    4
# 319        $3450      1320 Windswept Cmn        Livermore    CA   94550    3
#
#     Baths  SqFt
# 0       2  1466
# 1       5  1392
# 2       2  1276
# 3       2  1740
# 4       2  1355
# ..    ...   ...
# 315     0     0
# 316     0     0
# 317     5  3908
# 318     3  3100
# 319     5  1757
#
# [320 rows x 8 columns]

# %% [markdown]
# # Final Result

# %%
dff
# Out:
#     Monthly Rent                 Address             City State ZipCode Beds  \
# 0          $4472      350 Sharon Park Dr       Menlo Park    CA   94025    3
# 1          $3305       55 Triton Park Ln      Foster City    CA   94404    3
# 2          $3085   1030 Indian Wells Ave        Sunnyvale    CA   94085    2
# 3          $7300          570 La Mesa Dr   Portola Valley    CA   94028    3
# 4          $3877        555 E Evelyn Ave    Mountain View    CA   94041    3
# ..           ...                     ...              ...   ...     ...  ...
# 315        $3000             425 2nd Ave    San Francisco    CA   94118    0
# 316        $2900        280 Easy St #501    Mountain View    CA   94043    0
# 317        $6850   6840 Charing Cross Rd         Berkeley    CA   94705    5
# 318       $12000            111 30th Ave    San Francisco    CA   94121    4
# 319        $3450      1320 Windswept Cmn        Livermore    CA   94550    3
#
#     Baths  SqFt
# 0       2  1466
# 1       5  1392
# 2       2  1276
# 3       2  1740
# 4       2  1355
# ..    ...   ...
# 315     0     0
# 316     0     0
# 317     5  3908
# 318     3  3100
# 319     5  1757
#
# [320 rows x 8 columns]

# %%
#export data frame as a csv file, ready for further analysis
dff.to_csv("cleanedrental.csv", index=False)

print("done")
# Out:
# done
